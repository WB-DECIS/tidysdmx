# %% [markdown]
# # Overview

# %% [markdown]
# The purpose of this notebook is to understand the logic of `transform_source_to_target` developed by Tony, then to improve it and make it more robust.
#
# **Note: This notebook is for development purposes and it is not intended to be used in production nor to be executed sequentially.**

# %% [markdown]
# # Setup

# %%
# import pysdmx as px

# %%
# from pysdmx.io.format import StructureFormat # To extract json format
# from pysdmx.api import fmr # CLient to connect to FMR
# from urllib.parse import urljoin

# %%
import pandas as pd
import json 

pd.set_option('display.max_columns', None)

# %%
# import csv file
raw = pd.read_csv("./wb_shp_bronze.csv")
raw.head()
# Out:
#          indicator  year countrycode     period welftype  spell  subgroup  \
# 0  WB.SP.meantotal  2008         ALB  2008-2012     CONS      1  National
# 1  WB.SP.meantotal  2012         ALB  2008-2012     CONS      2  National
# 2  WB.SP.meantotal  2014         ALB  2014-2017     CONS      1  National
# 3  WB.SP.meantotal  2017         ALB  2014-2017     CONS      2  National
# 4  WB.SP.meantotal  2013         ARE  2013-2018      INC      1  National
#
#        value
# 0  10.038170
# 1   9.517231
# 2  10.141310
# 3  12.411220
# 4  72.450951

# %%
# import json mapping file
mapping_file_path = "./master_mapping_wb_shp.json"
with open(mapping_file_path, 'r') as f:
    mapping = json.load(f)
mapping.keys()
# Out:
# dict_keys(['schema_version', 'dsd_id', 'components', 'representation'])

# %%
type(mapping)
# Out:
# dict

# %% [markdown]
# # transform_source_to_target

# %% [markdown]
# ## Line by line

# %%
# corrupted_mapping
# Delete components from mapping 
no_comp_mapping = mapping.copy()
del no_comp_mapping['components']
print(no_comp_mapping.keys())
# Out:
# dict_keys(['schema_version', 'dsd_id', 'representation'])

# %%
# Create an empty DataFrame with columns as defined in components_map['TARGET']
components_map = mapping["components"]
components_map
# Out:
# [{'SOURCE': 'NA', 'TARGET': 'FREQ'},
#  {'SOURCE': 'countrycode', 'TARGET': 'REF_AREA'},
#  {'SOURCE': 'indicator', 'TARGET': 'INDICATOR'},
#  {'SOURCE': 'NA', 'TARGET': 'SEX'},
#  {'SOURCE': 'NA', 'TARGET': 'AGE'},
#  {'SOURCE': 'NA', 'TARGET': 'URBANISATION'},
#  {'SOURCE': 'indicator', 'TARGET': 'UNIT_MEASURE'},
#  {'SOURCE': 'welftype', 'TARGET': 'COMP_BREAKDOWN_1'},
#  {'SOURCE': 'period', 'TARGET': 'COMP_BREAKDOWN_2'},
#  {'SOURCE': 'NA', 'TARGET': 'COMP_BREAKDOWN_3'},
#  {'SOURCE': 'year', 'TARGET': 'TIME_PERIOD'},
#  {'SOURCE': 'NA', 'TARGET': 'AGG_METHOD'},
#  {'SOURCE': 'indicator', 'TARGET': 'UNIT_TYPE'},
#  {'SOURCE': 'NA', 'TARGET': 'DECIMALS'},
#  {'SOURCE': 'NA', 'TARGET': 'DATABASE_ID'},
#  {'SOURCE': 'NA', 'TARGET': 'TIME_FORMAT'},
#  {'SOURCE': 'NA', 'TARGET': 'COMMENT_TS'},
#  {'SOURCE': 'NA', 'TARGET': 'COMMENT_OBS'},
#  {'SOURCE': 'NA', 'TARGET': 'UNIT_MULT'},
#  {'SOURCE': 'NA', 'TARGET': 'OBS_STATUS'},
#  {'SOURCE': 'NA', 'TARGET': 'DATA_SOURCE'},
#  {'SOURCE': 'NA', 'TARGET': 'OBS_CONF'},
#  {'SOURCE': 'value', 'TARGET': 'OBS_VALUE'}]

# %%
try: 
    no_comp_mapping['components']
except KeyError as e:
    print(f"The mapping file should contain 'components' key. Please make sure the mapping file has this key.")
# Out:
# The mapping file should contain 'components' key. Please make sure the mapping file has this key.

# %%
components_map
# Out:
# [{'SOURCE': 'NA', 'TARGET': 'FREQ'},
#  {'SOURCE': 'countrycode', 'TARGET': 'REF_AREA'},
#  {'SOURCE': 'indicator', 'TARGET': 'INDICATOR'},
#  {'SOURCE': 'NA', 'TARGET': 'SEX'},
#  {'SOURCE': 'NA', 'TARGET': 'AGE'},
#  {'SOURCE': 'NA', 'TARGET': 'URBANISATION'},
#  {'SOURCE': 'indicator', 'TARGET': 'UNIT_MEASURE'},
#  {'SOURCE': 'welftype', 'TARGET': 'COMP_BREAKDOWN_1'},
#  {'SOURCE': 'period', 'TARGET': 'COMP_BREAKDOWN_2'},
#  {'SOURCE': 'NA', 'TARGET': 'COMP_BREAKDOWN_3'},
#  {'SOURCE': 'year', 'TARGET': 'TIME_PERIOD'},
#  {'SOURCE': 'NA', 'TARGET': 'AGG_METHOD'},
#  {'SOURCE': 'indicator', 'TARGET': 'UNIT_TYPE'},
#  {'SOURCE': 'NA', 'TARGET': 'DECIMALS'},
#  {'SOURCE': 'NA', 'TARGET': 'DATABASE_ID'},
#  {'SOURCE': 'NA', 'TARGET': 'TIME_FORMAT'},
#  {'SOURCE': 'NA', 'TARGET': 'COMMENT_TS'},
#  {'SOURCE': 'NA', 'TARGET': 'COMMENT_OBS'},
#  {'SOURCE': 'NA', 'TARGET': 'UNIT_MULT'},
#  {'SOURCE': 'NA', 'TARGET': 'OBS_STATUS'},
#  {'SOURCE': 'NA', 'TARGET': 'DATA_SOURCE'},
#  {'SOURCE': 'NA', 'TARGET': 'OBS_CONF'},
#  {'SOURCE': 'value', 'TARGET': 'OBS_VALUE'}]

# %%
if isinstance(components_map, list):
	components_map = pd.DataFrame(components_map)

# %%
components_map
# Out:
#          SOURCE            TARGET
# 0            NA              FREQ
# 1   countrycode          REF_AREA
# 2     indicator         INDICATOR
# 3            NA               SEX
# 4            NA               AGE
# 5            NA      URBANISATION
# 6     indicator      UNIT_MEASURE
# 7      welftype  COMP_BREAKDOWN_1
# 8        period  COMP_BREAKDOWN_2
# 9            NA  COMP_BREAKDOWN_3
# 10         year       TIME_PERIOD
# 11           NA        AGG_METHOD
# 12    indicator         UNIT_TYPE
# 13           NA          DECIMALS
# 14           NA       DATABASE_ID
# 15           NA       TIME_FORMAT
# 16           NA        COMMENT_TS
# 17           NA       COMMENT_OBS
# 18           NA         UNIT_MULT
# 19           NA        OBS_STATUS
# 20           NA       DATA_SOURCE
# 21           NA          OBS_CONF
# 22        value         OBS_VALUE

# %%
result_df = pd.DataFrame(columns=components_map["TARGET"].values)
result_df
# Out:
# Empty DataFrame
# Columns: [FREQ, REF_AREA, INDICATOR, SEX, AGE, URBANISATION, UNIT_MEASURE, COMP_BREAKDOWN_1, COMP_BREAKDOWN_2, COMP_BREAKDOWN_3, TIME_PERIOD, AGG_METHOD, UNIT_TYPE, DECIMALS, DATABASE_ID, TIME_FORMAT, COMMENT_TS, COMMENT_OBS, UNIT_MULT, OBS_STATUS, DATA_SOURCE, OBS_CONF, OBS_VALUE]
# Index: []

# %%
for _, row in components_map.iterrows():
	source_col = row["SOURCE"]
	target_col = row["TARGET"]

	# If source_col exists in raw, populate the corresponding column in result_df
	if source_col in raw.columns:
		result_df[target_col] = raw[source_col]

# %%
result_df
# Out:
#      FREQ REF_AREA        INDICATOR  SEX  AGE URBANISATION     UNIT_MEASURE  \
# 0     NaN      ALB  WB.SP.meantotal  NaN  NaN          NaN  WB.SP.meantotal
# 1     NaN      ALB  WB.SP.meantotal  NaN  NaN          NaN  WB.SP.meantotal
# 2     NaN      ALB  WB.SP.meantotal  NaN  NaN          NaN  WB.SP.meantotal
# 3     NaN      ALB  WB.SP.meantotal  NaN  NaN          NaN  WB.SP.meantotal
# 4     NaN      ARE  WB.SP.meantotal  NaN  NaN          NaN  WB.SP.meantotal
# ...   ...      ...              ...  ...  ...          ...              ...
# 6907  NaN      ZAF  WB.SP.growthb40  NaN  NaN          NaN  WB.SP.growthb40
# 6908  NaN      ZMB  WB.SP.growthb40  NaN  NaN          NaN  WB.SP.growthb40
# 6909  NaN      ZMB  WB.SP.growthb40  NaN  NaN          NaN  WB.SP.growthb40
# 6910  NaN      ZWE  WB.SP.growthb40  NaN  NaN          NaN  WB.SP.growthb40
# 6911  NaN      ZWE  WB.SP.growthb40  NaN  NaN          NaN  WB.SP.growthb40
#
#      COMP_BREAKDOWN_1 COMP_BREAKDOWN_2 COMP_BREAKDOWN_3  TIME_PERIOD  \
# 0                CONS        2008-2012              NaN         2008
# 1                CONS        2008-2012              NaN         2012
# 2                CONS        2014-2017              NaN         2014
# 3                CONS        2014-2017              NaN         2017
# 4                 INC        2013-2018              NaN         2013
# ...               ...              ...              ...          ...
# 6907             CONS        2010-2014              NaN         2014
# 6908             CONS        2010-2015              NaN         2010
# 6909             CONS        2010-2015              NaN         2015
# 6910             CONS        2011-2017              NaN         2011
# 6911             CONS        2011-2017              NaN         2017
#
#      AGG_METHOD        UNIT_TYPE DECIMALS DATABASE_ID TIME_FORMAT COMMENT_TS  \
# 0           NaN  WB.SP.meantotal      NaN         NaN         NaN        NaN
# 1           NaN  WB.SP.meantotal      NaN         NaN         NaN        NaN
# 2           NaN  WB.SP.meantotal      NaN         NaN         NaN        NaN
# 3           NaN  WB.SP.meantotal      NaN         NaN         NaN        NaN
# 4           NaN  WB.SP.meantotal      NaN         NaN         NaN        NaN
# ...         ...              ...      ...         ...         ...        ...
# 6907        NaN  WB.SP.growthb40      NaN         NaN         NaN        NaN
# 6908        NaN  WB.SP.growthb40      NaN         NaN         NaN        NaN
# 6909        NaN  WB.SP.growthb40      NaN         NaN         NaN        NaN
# 6910        NaN  WB.SP.growthb40      NaN         NaN         NaN        NaN
# 6911        NaN  WB.SP.growthb40      NaN         NaN         NaN        NaN
#
#      COMMENT_OBS UNIT_MULT OBS_STATUS DATA_SOURCE OBS_CONF  OBS_VALUE
# 0            NaN       NaN        NaN         NaN      NaN  10.038170
# 1            NaN       NaN        NaN         NaN      NaN   9.517231
# 2            NaN       NaN        NaN         NaN      NaN  10.141310
# 3            NaN       NaN        NaN         NaN      NaN  12.411220
# 4            NaN       NaN        NaN         NaN      NaN  72.450951
# ...          ...       ...        ...         ...      ...        ...
# 6907         NaN       NaN        NaN         NaN      NaN  -1.360486
# 6908         NaN       NaN        NaN         NaN      NaN  -1.976578
# 6909         NaN       NaN        NaN         NaN      NaN  -1.976578
# 6910         NaN       NaN        NaN         NaN      NaN  -3.749366
# 6911         NaN       NaN        NaN         NaN      NaN  -3.749366
#
# [6912 rows x 23 columns]

# %%
print(raw.shape)
print(result_df.shape)
# Out:
# (6912, 8)
# (6912, 23)

# %% [markdown]
# ## function

# %%
def transform_source_to_target(
		raw: pd.DataFrame, 
		mapping: dict
	) -> pd.DataFrame:
	"""Transforms raw DataFrame into the format defined by components_map.
	
	This function creates a new dataframe with columns as defined in components_map['TARGET'] and populates it with data from the raw DataFrame based on the columns names in the ['SOURCE'].

	Args:
		raw (pd.DataFrame): The input DataFrame with raw data.
		mapping (dict): The master mapping dictionary containing a mapping between the input file columns, and the columns defined in the schema.

	Returns:
		pd.DataFrame: The transformed DataFrame with columns as defined in components_map['TARGET'].
	"""
	# Create an empty DataFrame with columns as defined in components_map['TARGET']
	try: 
		components_map = mapping["components"]

		# If the components_map is a list, create a dataframe with source and target columns
		if isinstance(components_map, list):
			components_map = pd.DataFrame(components_map)
		
		# Create an empty DataFrame with target columns
		result_df = pd.DataFrame(columns=components_map["TARGET"].values)

		# Iterate over the components_map DataFrame and map the columns
		for _, row in components_map.iterrows():
			source_col = row["SOURCE"]
			target_col = row["TARGET"]

			# If source_col exists in raw, populate the corresponding column in result_df
			if source_col in raw.columns:
				result_df[target_col] = raw[source_col]

		return result_df
	
	except KeyError as e:
		raise KeyError("The mapping file should contain 'components' key. Please make sure the mapping file has this key.") from e

# %% [markdown]
# ## Adding tests

# %%
test_df = pd.DataFrame({
            "col_a": [1, 2, 3],
            "col_b": ["x", "y", "z"],
            "col_extra": [10, 20, 30]
        })

test_mapping = {
            "components": [
                {"SOURCE": "col_a", "TARGET": "target_a"},
                {"SOURCE": "col_b", "TARGET": "target_b"},
                {"SOURCE": "NA", "TARGET": "target_c"}
            ]
        }

# %%
result_df = transform_source_to_target(test_df, test_mapping)
print(result_df)
# Out:
#    target_a target_b target_c
# 0         1        x      NaN
# 1         2        y      NaN
# 2         3        z      NaN

# %%
result_df["target_c"][0]
# Out:
# nan
